# %% [markdown]
# Assignment 2 - Working with Pandas
# This assignment demonstrates how to create DataFrames, perform statistical analysis, filter data, group data, and export results to CSV using the Pandas library.

# %%
import pandas as pd


data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve'],
    'Age': [24, 27, 22, 32, 29],
    'Department': ['HR', 'Finance', 'IT', 'Marketing', 'HR'],
    'Salary': [45000, 54000, 50000, 62000, 47000]
}
df = pd.DataFrame(data)


print("First 5 rows:\n", df.head())


print("\nSummary Statistics:\n", df[['Age', 'Salary']].describe())


hr_avg_salary = df[df['Department'] == 'HR']['Salary'].mean()
print("\nAverage HR Salary:", hr_avg_salary)


df['Bonus'] = df['Salary'] * 0.10
print("\nDataFrame with Bonus:\n", df)


filtered_df = df[(df['Age'] >= 25) & (df['Age'] <= 30)]
print("\nEmployees aged 25-30:\n", filtered_df)


dept_avg_salary = df.groupby('Department')['Salary'].mean()
print("\nAverage Salary by Department:\n", dept_avg_salary)


sorted_df = df.sort_values(by='Salary', ascending=True)
sorted_df.to_csv('sorted_employees.csv', index=False)
print("\nSorted DataFrame saved to 'sorted_employees.csv'")
# Out:
# First 5 rows:
#        Name  Age Department  Salary
# 0    Alice   24         HR   45000
# 1      Bob   27    Finance   54000
# 2  Charlie   22         IT   50000
# 3    Diana   32  Marketing   62000
# 4      Eve   29         HR   47000
#
# Summary Statistics:
#               Age        Salary
# count   5.000000      5.000000
# mean   26.800000  51600.000000
# std     3.962323   6730.527468
# min    22.000000  45000.000000
# 25%    24.000000  47000.000000
# 50%    27.000000  50000.000000
# 75%    29.000000  54000.000000
# max    32.000000  62000.000000
#
# Average HR Salary: 46000.0
#
# DataFrame with Bonus:
#        Name  Age Department  Salary   Bonus
# 0    Alice   24         HR   45000  4500.0
# 1      Bob   27    Finance   54000  5400.0
# 2  Charlie   22         IT   50000  5000.0
# 3    Diana   32  Marketing   62000  6200.0
# 4      Eve   29         HR   47000  4700.0
#
# Employees aged 25-30:
#    Name  Age Department  Salary   Bonus
# 1  Bob   27    Finance   54000  5400.0
# ...
